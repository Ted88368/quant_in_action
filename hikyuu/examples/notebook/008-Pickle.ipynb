# %%
# %matplotlib inline
# %time from hikyuu.interactive import *

# %%
k = get_kdata('sh000001', -100)

# %%
import pickle

with open("temp", 'wb') as f:
    pickle.dump(k, f)

# %%
hku_save(k, "temp")

# %%
k2 = KData()
hku_load(k2, "temp")

# %%
k2.plot()
