# %%
# %matplotlib inline
# %time from hikyuu.interactive import *
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# 股票代码组合
codes = ['sh000001','sh601012','sh600438','sh601615']

# %%
for code in codes:
    s = sm[code]
    k = s.get_kdata(Query(-200))
    # 绘制亚历山大.艾尔德交易系统图形，《走进我的交易室》, 2007
    el.draw(s)
# Out:
# c:\Users\huzhe\.conda\envs\hikyuu\lib\site-packages\hikyuu\draw\drawplot\matplotlib_draw.py:363: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   axes.plot(py_indicatr, '-', label=label, *args, **kwargs)
