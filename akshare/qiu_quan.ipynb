# %%
import akshare as ak

index_fear_greed_funddb_df = ak.index_fear_greed_funddb(symbol="上证指数")
print(index_fear_greed_funddb_df)
# Out:
#            date   fear    index
# 0    2023-10-26  23.56  2988.30
# 1    2023-10-27  35.01  3017.78
# 2    2023-10-30  33.44  3021.55
# 3    2023-10-31  27.43  3018.77
# 4    2023-11-01  32.62  3023.08
# ..          ...    ...      ...
# 237  2024-10-21  99.59  3268.11
# 238  2024-10-22  99.09  3285.87
# 239  2024-10-23  99.09  3302.80
# 240  2024-10-24  88.04  3280.26
# 241  2024-10-25  89.91  3299.70
#
# [242 rows x 3 columns]

# %%
import akshare as ak

import matplotlib.pyplot as plt
import numpy as np

from aquarel import load_theme

# ['arctic_dark', 'arctic_light', 'boxy_dark', 'boxy_light', 'gruvbox_dark', 'gruvbox_light', 'minimal_dark', 'minimal_light', 'scientific', 'umbra_dark', 'umbra_light']
theme = load_theme("scientific")
theme.apply()

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

#print(plt.style.available)
#plt.style.use('seaborn-v0_8-ticks')

index_fear_greed_funddb_df = ak.index_fear_greed_funddb()
print(index_fear_greed_funddb_df)

# 创建一个绘图对象
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.set_ylabel('上证指数', color='b')
ax1.plot(index_fear_greed_funddb_df['date'], index_fear_greed_funddb_df['index'], label = "上证指数")

# 创建第二个 Y 轴并绘制数据
ax2 = ax1.twinx()  # 使用 twinx() 共享 x 轴
ax2.set_ylabel('恐贪指数', color='b')
ax2.plot(index_fear_greed_funddb_df['date'], index_fear_greed_funddb_df['fear'],label ="恐贪指数", color = 'red')

# 添加图例
fig.tight_layout()  # 自动调整布局

theme.apply_transforms()

plt.show()
# Out:
#            date   fear    index
# 0    2023-10-27  35.01  3017.78
# 1    2023-10-30  33.44  3021.55
# 2    2023-10-31  27.43  3018.77
# 3    2023-11-01  32.62  3023.08
# 4    2023-11-02  20.43  3009.41
# ..          ...    ...      ...
# 236  2024-10-21  99.59  3268.11
# 237  2024-10-22  99.09  3285.87
# 238  2024-10-23  99.09  3302.80
# 239  2024-10-24  88.04  3280.26
# 240  2024-10-25  89.91  3299.70
#
# [241 rows x 3 columns]

# %%
import akshare as ak

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

#print(plt.style.available)
#plt.style.use('seaborn-v0_8-ticks')

index_fear_greed_funddb_df = ak.index_fear_greed_funddb()
print(index_fear_greed_funddb_df.head(10))



sns.relplot(
    data=index_fear_greed_funddb_df, kind="line",
    x="date", y="index",
    facet_kws=dict(sharex=False),
)
# Out:
#          date   fear    index
# 0  2023-10-27  35.01  3017.78
# 1  2023-10-30  33.44  3021.55
# 2  2023-10-31  27.43  3018.77
# 3  2023-11-01  32.62  3023.08
# 4  2023-11-02  20.43  3009.41
# 5  2023-11-03  30.48  3030.80
# 6  2023-11-06  57.17  3058.41
# 7  2023-11-07  62.44  3057.27
# 8  2023-11-08  47.86  3052.37
# 9  2023-11-09  33.77  3053.28
