# %% [markdown]
# ##### 只支持Python3.12以上版本
# ```shell
# # 环境准备
# conda create --name py312 python=3.12
# conda activate py312
#
# # 安装akshare
# pip install akshare --upgrade -i https://pypi.tuna.tsinghua.edu.cn/simple
# ```

# %%
# 数据说明 https://akshare.akfamily.xyz/data/index.html


import akshare as ak

# 上证数据
stock_sse_summary_df = ak.stock_sse_summary()

# 数据来源 http://www.sse.com.cn/market/stockdata/statistic/

# 修改dataframe的列名
stock_sse_summary_df.columns = ['项目','总貌','主板','创业板']
print(stock_sse_summary_df)

# %%
# 深圳证券交易所

import akshare as ak
stock_szse_summary_df = ak.stock_szse_summary(date="20240930")
print(stock_szse_summary_df)

# %%
# 绘制饼图

import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # 突出显示第二个切片
