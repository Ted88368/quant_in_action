# %%
# %matplotlib inline
# %time from hikyuu.interactive import *
# Out:
# CPU times: user 209 μs, sys: 5 μs, total: 214 μs
# Wall time: 229 μs

# %%
# 股票代码组合
codes = ['sh000001','sh603486']

# %%
for code in codes:
    s = sm[code]
    k = s.get_kdata(Query(-200))
    # 绘制亚历山大.艾尔德交易系统图形，《走进我的交易室》, 2007
    el.draw(s)
