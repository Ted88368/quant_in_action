# %%
import baostock as bs
import pandas as pd
import mplfinance as mpf
import numpy as np

# 登录baostock系统
lg = bs.login()

# 获取上证指数的历史K线数据，同时过滤非交易日
symbol = "sh.000001"  # 上证指数代码
start_date = '2024-01-01'
end_date = '2025-01-01'
frequency = 'd'  # 日线数据
fields = "date,open,high,low,close,volume"

# 获取股票数据
rs = bs.query_history_k_data(symbol,
                              "date,open,high,low,close,volume",
                              start_date=start_date,
                              end_date=end_date,
                              frequency="d",
                              adjustflag="3")  # adjustflag="3"表示不复权
data = rs.get_data()

# 去除空值
data = data.dropna()

# 将数据重新格式化以适应mplfinance的要求
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')

# 转换为float
data[['open', 'high', 'low', 'close', 'volume']] = data[['open', 'high', 'low', 'close', 'volume']].astype(float)

# 登出baostock系统
bs.logout()
# Out:
# login success!
# logout success!

# %%
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[9], line 13
#       6 line_data = pd.DataFrame({
#       7     'date': [point1, point2],
#       8     'line': [data['low'].loc[point1], data['low'].loc[point2]]
#       9 })
#      11 # 合并K线数据和连接线数据
#      12 # 使用 pd.merge_asof 进行连接
# ---> 13 merged_data = pd.merge_asof(data, line_data, on='date', direction='forward')
#      15 # 绘制K线图和连接线
#      16 mpf.plot(merged_data, type='candle', style='yahoo', volume=True, addplot=[
#      17     mpf.make_addplot(merged_data['line'], color='orange', secondary_y=False, linestyle='dashed', x_compat=True)
#      18 ], figsize=(10, 8))
#
# File c:\Users\huzhe\.conda\envs\py310\lib\site-packages\pandas\core\reshape\merge.py:688, in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     437 def merge_asof(
#     438     left: DataFrame | Series,
#     439     right: DataFrame | Series,
#    (...)
#     451     direction: str = "backward",
#     452 ) -> DataFrame:
#     453     """
#     454     Perform a merge by key distance.
#     455
#    (...)
#     686     4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN
#     687     """
# --> 688     op = _AsOfMerge(
#     689         left,
#     690         right,
#     691         on=on,
#     692         left_on=left_on,
#     693         right_on=right_on,
#     694         left_index=left_index,
#     695         right_index=right_index,
#     696         by=by,
#     697         left_by=left_by,
#     698         right_by=right_by,
#     699         suffixes=suffixes,
#     700         how="asof",
#     701         tolerance=tolerance,
#     702         allow_exact_matches=allow_exact_matches,
#     703         direction=direction,
#     704     )
#     705     return op.get_result()
#
# File c:\Users\huzhe\.conda\envs\py310\lib\site-packages\pandas\core\reshape\merge.py:1921, in _AsOfMerge.__init__(self, left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, how, tolerance, allow_exact_matches, direction)
#    1915     msg = (
#    1916         "allow_exact_matches must be boolean, "
#    1917         f"passed {self.allow_exact_matches}"
#    1918     )
#    1919     raise MergeError(msg)
# -> 1921 _OrderedMerge.__init__(
#    1922     self,
#    1923     left,
#    1924     right,
#    1925     on=on,
#    1926     left_on=left_on,
#    1927     right_on=right_on,
#    1928     left_index=left_index,
#    1929     right_index=right_index,
#    1930     how=how,
#    1931     suffixes=suffixes,
#    1932     fill_method=None,
#    1933 )
#
# File c:\Users\huzhe\.conda\envs\py310\lib\site-packages\pandas\core\reshape\merge.py:1837, in _OrderedMerge.__init__(self, left, right, on, left_on, right_on, left_index, right_index, suffixes, fill_method, how)
#    1823 def __init__(
#    1824     self,
#    1825     left: DataFrame | Series,
#    (...)
#    1834     how: JoinHow | Literal["asof"] = "outer",
#    1835 ) -> None:
#    1836     self.fill_method = fill_method
# -> 1837     _MergeOperation.__init__(
#    1838         self,
#    1839         left,
#    1840         right,
#    1841         on=on,
#    1842         left_on=left_on,
#    1843         left_index=left_index,
#    1844         right_index=right_index,
#    1845         right_on=right_on,
#    1846         how=how,
#    1847         suffixes=suffixes,
#    1848         sort=True,  # factorize sorts
#    1849     )
#
# File c:\Users\huzhe\.conda\envs\py310\lib\site-packages\pandas\core\reshape\merge.py:783, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     776     msg = (
#     777         "Not allowed to merge between different levels. "
#     778         f"({_left.columns.nlevels} levels on the left, "
#     779         f"{_right.columns.nlevels} on the right)"
#     780     )
#     781     raise MergeError(msg)
# --> 783 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     785 (
#     786     self.left_join_keys,
#     787     self.right_join_keys,
#    (...)
#     790     right_drop,
#     791 ) = self._get_merge_keys()
#     793 if left_drop:
#
# File c:\Users\huzhe\.conda\envs\py310\lib\site-packages\pandas\core\reshape\merge.py:1989, in _AsOfMerge._validate_left_right_on(self, left_on, right_on)
#    1986     ro_dtype = self.right.index.dtype
#    1988 if is_object_dtype(lo_dtype) or is_object_dtype(ro_dtype):
# -> 1989     raise MergeError(
#    1990         f"Incompatible merge dtype, {repr(ro_dtype)} and "
#    1991         f"{repr(lo_dtype)}, both sides must have numeric dtype"
#    1992     )
#    1994 # add 'by' to our key-list so we can have it in the
#    1995 # output as a key
#    1996 if self.left_by is not None:
#
# MergeError: Incompatible merge dtype, dtype('O') and DatetimeIndex(['2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05',
#                '2024-01-08', '2024-01-09', '2024-01-10', '2024-01-11',
#                '2024-01-12', '2024-01-15', '2024-01-16', '2024-01-17',
#                '2024-01-18', '2024-01-19', '2024-01-22', '2024-01-23',
#                '2024-01-24', '2024-01-25', '2024-01-26', '2024-01-29',
#                '2024-01-30', '2024-01-31', '2024-02-01', '2024-02-02',
#                '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08',
#                '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22',
#                '2024-02-23'],
#               dtype='datetime64[ns]', name='date', freq=None), both sides must have numeric dtype
