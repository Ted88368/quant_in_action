# %% [markdown]
# ##### 只支持Python3.12以上版本
# ```shell
# # 环境准备
# conda create --name py312 python=3.12
# conda activate py312
#
# # 安装akshare
# pip install akshare --upgrade -i https://pypi.tuna.tsinghua.edu.cn/simple
# ```

# %%
# 数据说明 https://akshare.akfamily.xyz/data/index.html


import akshare as ak

stock_sse_summary_df = ak.stock_sse_summary()
print(stock_sse_summary_df)

# %% [markdown]
# #### ETF
# ##### 单位净值
# 每个ETF份额的总资产净值除以已发行份额的数量，即为ETF的单位净值。
#
# ##### 累计净值
# 指自ETF成立以来的总回报，包括分红和资本增值。

# %%
import akshare as ak
fund_etf_fund_info_em_df = ak.fund_etf_fund_info_em(fund="159919", start_date="20240926", end_date="20240930")
print(fund_etf_fund_info_em_df)

fund_graded_fund_info_em_df = ak.fund_graded_fund_info_em(fund="159919")
print(fund_graded_fund_info_em_df.head(10))
# Out:
#          净值日期    单位净值    累计净值  日增长率 申购状态 赎回状态
# 0  2024-09-26  3.7117  1.6892   NaN         1
# 1  2024-09-27  3.8779  1.7597   NaN         1
#          净值日期    单位净值    累计净值   日增长率  申购状态  赎回状态
# 0  2024-09-27  3.8779  1.7597   4.48  场内买入  场内卖出
# 1  2024-09-26  3.7117  1.6892   4.23  场内买入  场内卖出
# 2  2024-09-25  3.5610  1.6252   1.49  场内买入  场内卖出
# 3  2024-09-24  3.5088  1.6030   4.33  场内买入  场内卖出
# 4  2024-09-23  3.3632  1.5412   0.36  场内买入  场内卖出
# 5  2024-09-20  3.3511  1.5361   0.16  场内买入  场内卖出
# 6  2024-09-19  3.3458  1.5338   0.80  场内买入  场内卖出
# 7  2024-09-18  3.3191  1.5225   0.35  场内买入  场内卖出
# 8  2024-09-13  3.3525  1.5175  -0.40  场内买入  场内卖出
# 9  2024-09-12  3.3661  1.5232  -0.42  场内买入  场内卖出

# %%
import akshare as ak

fund_etf_spot_em_df = ak.fund_etf_spot_em()
print(fund_etf_spot_em_df.head(10))
# Out:
#        代码          名称    最新价    涨跌额    涨跌幅        成交量           成交额    开盘价  \
# 0  588500  科创100ETF增强  1.242  0.207  20.00   392621.0  4.283634e+07  1.242
# 1  159777      创科技ETF  0.674  0.112  19.93   150697.0  9.498258e+06  0.569
# 2  588890   科创芯片ETF南方  1.219  0.201  19.74    44888.0  5.244437e+06  1.024
# 3  159773    创业板科技ETF  0.691  0.111  19.14   314465.0  2.025111e+07  0.591
# 4  159821  BOCI创业板ETF  0.752  0.108  16.77    85215.0  6.100469e+06  0.644
# 5  159991      创大盘ETF  0.428  0.060  16.30   373134.0  1.494418e+07  0.370
# 6  159603     双创龙头ETF  0.785  0.106  15.61   137085.0  1.024209e+07  0.685
# 7  159964    创业板ETF平安  1.255  0.151  13.68   135212.0  1.608846e+07  1.106
# 8  159681      创50ETF  0.834  0.093  12.55   782631.0  6.315188e+07  0.745
# 9  159682     创业50ETF  0.824  0.091  12.41  5310288.0  4.191918e+08  0.746
#
#      最高价    最低价     昨收    换手率        流通市值         总市值
# 0  1.242  0.989  1.035    NaN    24401574    24401574
# 1  0.674  0.569  0.562  87.21    11647101    11647101
# 2  1.222  1.019  1.018   8.83    61937390    61937390
# 3  0.696  0.591  0.580  32.12    67651056    67651056
# 4  0.773  0.644  0.644  50.97    12573440    12573440
# 5  0.431  0.370  0.368  14.54   109851838   109851838
# 6  0.801  0.685  0.679   0.54  1978256457  1978256457
# 7  1.300  1.106  1.104   3.15   538999769   538999769
# 8  0.867  0.745  0.741   7.92   823802128   823802128
# 9  0.828  0.746  0.733  15.56  2812565515  2812565515
