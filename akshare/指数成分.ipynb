# %%
import akshare as ak

index_stock_info_df = ak.index_stock_info()
print(index_stock_info_df.head())

index_stock_info_df.to_csv("index_stock_info.csv", index=False)
# Out:
#   index_code display_name publish_date
# 0     000001         上证指数   1991-07-15
# 1     000002         A股指数   1992-02-21
# 2     000003         B股指数   1992-02-21
# 3     000004         工业指数   1993-05-03
# 4     000005         商业指数   1993-05-03

# %%
index_stock_cons_df = ak.index_stock_cons(symbol="000688")
print(index_stock_cons_df.head())
# Out:
#      品种代码  品种名称        纳入日期
# 0  688702  盛科通信  2025-12-15
# 1  688220  翱捷科技  2025-12-15
# 2  688183  生益电子  2025-09-15
# 3  688608  恒玄科技  2025-06-16
# 4  688578   艾力斯  2025-03-17
